# %%
import nltk
import numpy as np
from nltk.corpus import stopwords
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Lambda, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to C:\Users\UTKARSH
# [nltk_data]     BRAHMANKAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\UTKARSH
# [nltk_data]     BRAHMANKAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\UTKARSH
# [nltk_data]     BRAHMANKAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
with open("CBOW.txt","r",encoding='utf-8') as file:
    text=file.read().lower()

tokens=nltk.word_tokenize(text)
tokens = [t for t in tokens if t.isalpha() and t not in stop_words]

tokenizer=Tokenizer()
tokenizer.fit_on_texts(tokens)
word2idx=tokenizer.word_index
indx2word={v:k for k,v in word2idx.items()}
vocab_size=len(word2idx)+1

# %%
def generate_cbow_data(tokens,window_size):
    data=[]
    for i in range (window_size,len(tokens)-window_size):
        context=[]
        for j in range (-window_size,window_size+1):
            if j!=0:
                context.append(word2idx[tokens[i+j]])
        target=word2idx[tokens[i]]
        data.append((context,target))
    return data

window_size=2
data=generate_cbow_data(tokens,window_size)
contexts=[x[0] for x in data]
targets=[x[1] for x in data]

X=pad_sequences(contexts,maxlen=2* window_size,padding='pre')
y=to_categorical(targets,num_classes=vocab_size)
print(f"Training samples: {X.shape[0]}")
# Out:
# Training samples: 82

# %%
embedding_dim=100
model=Sequential()
model.add(Embedding(input_dim=vocab_size,output_dim=embedding_dim,input_length=2*window_size))
model.add(Lambda(lambda x:K.mean(x,axis=1),output_shape=(embedding_dim,)))
model.add(Dense(vocab_size,activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# C:\Users\UTKARSH BRAHMANKAR\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.fit(X, y, epochs=100, batch_size=50,verbose=1)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0229 - loss: 4.0774
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0444 - loss: 4.0681
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0688 - loss: 4.0598
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1590 - loss: 4.0518
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2589 - loss: 4.0433
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3343 - loss: 4.0344
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3654 - loss: 4.0268
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4904 - loss: 4.0178
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4985 - loss: 4.0091
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5496 - loss: 3.9998
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5429 - loss: 3.9901
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5473 - loss: 3.9841
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5688 - loss: 3.9736
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5702 - loss: 3.9640
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6080 - loss: 3.9544
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6561 - loss: 3.9434
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6176 - loss: 3.9353
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6324 - loss: 3.9255
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6657 - loss: 3.9108
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6686 - loss: 3.8985
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6820 - loss: 3.8920
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6967 - loss: 3.8764
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6967 - loss: 3.8658
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7197 - loss: 3.8492
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7130 - loss: 3.8367
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7049 - loss: 3.8262
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6915 - loss: 3.8110
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6982 - loss: 3.7980
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6886 - loss: 3.7847
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7020 - loss: 3.7694
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6901 - loss: 3.7501
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6967 - loss: 3.7329
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6967 - loss: 3.7214
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6767 - loss: 3.6986
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7034 - loss: 3.6872
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7167 - loss: 3.6563
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7315 - loss: 3.6417
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6982 - loss: 3.6254
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7167 - loss: 3.6043
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6834 - loss: 3.5889
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6967 - loss: 3.5633
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7034 - loss: 3.5407
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7034 - loss: 3.5178
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7101 - loss: 3.4996
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6701 - loss: 3.4886
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7034 - loss: 3.4510
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7020 - loss: 3.4288
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7020 - loss: 3.4033
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7086 - loss: 3.3759
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7220 - loss: 3.3544
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6820 - loss: 3.3261
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7020 - loss: 3.2997
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6538 - loss: 3.2853
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6672 - loss: 3.2524
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6753 - loss: 3.2376
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6805 - loss: 3.1938
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6605 - loss: 3.1641
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6538 - loss: 3.1514
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6672 - loss: 3.1156
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6938 - loss: 3.0711
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6657 - loss: 3.0703
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6657 - loss: 3.0192
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6872 - loss: 3.0137
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6738 - loss: 2.9658
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6872 - loss: 2.9143
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6672 - loss: 2.9161
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6753 - loss: 2.8790
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6886 - loss: 2.8438
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6953 - loss: 2.8081
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6820 - loss: 2.7972
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6553 - loss: 2.7615
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7020 - loss: 2.7189
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6753 - loss: 2.7141
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7101 - loss: 2.6805
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6834 - loss: 2.6768
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6767 - loss: 2.6289
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7034 - loss: 2.5801
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6701 - loss: 2.5573
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7034 - loss: 2.5081
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7034 - loss: 2.4962
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7234 - loss: 2.4433
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7115 - loss: 2.4341
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6967 - loss: 2.3975
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7249 - loss: 2.3674
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7115 - loss: 2.3416
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6849 - loss: 2.3294
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6982 - loss: 2.2956
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7197 - loss: 2.2502
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7478 - loss: 2.2030
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7545 - loss: 2.1807
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7411 - loss: 2.1802
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7426 - loss: 2.1546
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7574 - loss: 2.0968
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7507 - loss: 2.0926
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7789 - loss: 2.0543
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7870 - loss: 2.0481
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7603 - loss: 2.0231
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7803 - loss: 1.9474
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7885 - loss: 1.9276
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7885 - loss: 1.9293

# %%
embeddings=model.layers[0].get_weights()[0]
for word in list(word2idx.keys())[:10]:
    print(f"{word}:{embeddings[word2idx[word]][:10]}")
# Out:
# influenza:[-0.01027951 -0.30078283 -0.15246384 -0.03800527 -0.07958699 -0.06314165
#  -0.00567844 -0.10172644  0.25050893  0.17349605]
# virus:[ 0.03767065 -0.00107381  0.06819395 -0.07838093  0.2625371   0.05990122
#  -0.07577944  0.00734517 -0.4451578   0.16453314]
# transmission:[ 0.19549832  0.14031906  0.12673391 -0.16028608  0.13717674  0.06604031
#   0.26629412 -0.31679893  0.05012747  0.02016014]
# serial:[ 0.13859345 -0.16365542  0.36201993 -0.16518399  0.25095743  0.05008023
#   0.3840966  -0.3262652  -0.31572375  0.4027784 ]
# interval:[ 0.0698977  -0.2868635   0.47709492 -0.141394    0.3624475  -0.4449574
#  -0.24338785 -0.10716271 -0.07822799  0.44981706]
# days:[ 0.25452623 -0.14476193  0.3112194  -0.16852649  0.13043624  0.00870123
#   0.03084818 -0.18850586  0.05373946  0.26630917]
# viruses:[ 0.25412437 -0.24210656  0.03196465 -0.04723653 -0.05466776  0.23759036
#   0.21340668 -0.28646255  0.27838844  0.0494804 ]
# shorter:[ 0.21812955 -0.14889562 -0.01437315  0.15325686  0.2030873  -0.0882653
#   0.02387599 -0.19049263  0.00665987  0.17996243]
# time:[ 0.08603223 -0.00858046 -0.01307016  0.22596982  0.18964511 -0.15332225
#  -0.23413141 -0.06697376 -0.23183975  0.08577279]
# appearance:[-0.25738934  0.12778802  0.16230114 -0.31734228 -0.03078934  0.01951104
#   0.23962702 -0.3860734  -0.04900864  0.41040587]

# %%
def predict_target_word(context_words, tokenizer, model, window_size=2):
    context_indices = [tokenizer.word_index.get(w, 0) for w in context_words if w in tokenizer.word_index]
    X_test = pad_sequences([context_indices], maxlen=2 * window_size, padding='pre')
    # Predict
    pred_probs = model.predict(X_test, verbose=0)
    target_idx = np.argmax(pred_probs)
    return idx2word.get(target_idx, None)
