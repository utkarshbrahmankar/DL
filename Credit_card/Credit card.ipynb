# %%
# ====== 1. Import Required Libraries ======
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

# ====== 2. Load Dataset ======
data = pd.read_csv("creditcard.csv")
X = data.drop(columns=['Class'])
y = data['Class']

# Scale 'Time' and 'Amount' features
scaler = StandardScaler()
X[['Time', 'Amount']] = scaler.fit_transform(X[['Time', 'Amount']])

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Isolate normal transactions for training
X_train_normal = X_train[y_train == 0]

# ====== 3. Build Autoencoder ======
input_dim = X_train_normal.shape[1]
input_layer = Input(shape=(input_dim,))

# Encoder
encoder = Dense(14, activation='relu')(input_layer)
encoder = Dense(7, activation='relu')(encoder)
latent = Dense(3, activation='relu')(encoder)

# Decoder
decoder = Dense(7, activation='relu')(latent)
decoder = Dense(14, activation='relu')(decoder)
output_layer = Dense(input_dim, activation='linear')(decoder)

# Autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
autoencoder.summary()

# ====== 4. Train Autoencoder ======
history = autoencoder.fit(
    X_train_normal, X_train_normal,
    epochs=50,          # Increased epochs for better convergence
    batch_size=256,
    shuffle=True,
    validation_split=0.2,
    verbose=1
)

# ====== 5. Determine Anomaly Threshold ======
# Predict reconstruction for normal training data
X_train_normal_pred = autoencoder.predict(X_train_normal)
mse_train_normal = np.mean(np.square(X_train_normal_pred - X_train_normal), axis=1)

# Threshold: 95th percentile of normal reconstruction errors
threshold = np.percentile(mse_train_normal, 95)
print(f"\nAnomaly Detection Threshold: {threshold:.6f}")

# ====== 6. Predict Anomalies on Test Set ======
X_test_pred = autoencoder.predict(X_test)
mse_test = np.mean(np.square(X_test_pred - X_test), axis=1)

# Classify anomalies
y_pred = (mse_test > threshold).astype(int)

# ====== 7. Evaluate Performance ======
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 30)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 14)                  │             434 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │             105 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │              24 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 7)                   │              28 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 14)                  │             112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 30)                  │             450 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,153 (4.50 KB)
#  Trainable params: 1,153 (4.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.9731 - mae: 0.6366 - val_loss: 0.7300 - val_mae: 0.5692
# Epoch 2/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7072 - mae: 0.5572 - val_loss: 0.6705 - val_mae: 0.5413
# Epoch 3/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6660 - mae: 0.5370 - val_loss: 0.6388 - val_mae: 0.5306
# Epoch 4/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6275 - mae: 0.5263 - val_loss: 0.6152 - val_mae: 0.5245
# Epoch 5/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6101 - mae: 0.5208 - val_loss: 0.5907 - val_mae: 0.5131
# Epoch 6/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5882 - mae: 0.5115 - val_loss: 0.5760 - val_mae: 0.5091
# Epoch 7/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5758 - mae: 0.5069 - val_loss: 0.5638 - val_mae: 0.5037
# Epoch 8/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5584 - mae: 0.5014 - val_loss: 0.5551 - val_mae: 0.4992
# Epoch 9/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5491 - mae: 0.4964 - val_loss: 0.5476 - val_mae: 0.4957
# Epoch 10/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5397 - mae: 0.4926 - val_loss: 0.5416 - val_mae: 0.4941
# Epoch 11/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5401 - mae: 0.4916 - val_loss: 0.5353 - val_mae: 0.4909
# Epoch 12/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5349 - mae: 0.4898 - val_loss: 0.5302 - val_mae: 0.4883
# Epoch 13/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5259 - mae: 0.4862 - val_loss: 0.5252 - val_mae: 0.4864
# Epoch 14/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5221 - mae: 0.4853 - val_loss: 0.5230 - val_mae: 0.4868
# Epoch 15/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5228 - mae: 0.4851 - val_loss: 0.5186 - val_mae: 0.4846
# Epoch 16/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5195 - mae: 0.4834 - val_loss: 0.5161 - val_mae: 0.4836
# Epoch 17/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5158 - mae: 0.4827 - val_loss: 0.5133 - val_mae: 0.4827
# Epoch 18/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5075 - mae: 0.4805 - val_loss: 0.5110 - val_mae: 0.4820
# Epoch 19/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5071 - mae: 0.4798 - val_loss: 0.5076 - val_mae: 0.4811
# Epoch 20/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5057 - mae: 0.4795 - val_loss: 0.5062 - val_mae: 0.4800
# Epoch 21/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5031 - mae: 0.4785 - val_loss: 0.5035 - val_mae: 0.4788
# Epoch 22/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5066 - mae: 0.4789 - val_loss: 0.5032 - val_mae: 0.4782
# Epoch 23/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5060 - mae: 0.4784 - val_loss: 0.4996 - val_mae: 0.4779
# Epoch 24/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4996 - mae: 0.4771 - val_loss: 0.4993 - val_mae: 0.4779
# Epoch 25/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4991 - mae: 0.4770 - val_loss: 0.5015 - val_mae: 0.4799
# Epoch 26/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4984 - mae: 0.4756 - val_loss: 0.4964 - val_mae: 0.4766
# Epoch 27/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4957 - mae: 0.4757 - val_loss: 0.4953 - val_mae: 0.4760
# Epoch 28/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4923 - mae: 0.4749 - val_loss: 0.5037 - val_mae: 0.4799
# Epoch 29/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4909 - mae: 0.4751 - val_loss: 0.4946 - val_mae: 0.4758
# Epoch 30/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4893 - mae: 0.4732 - val_loss: 0.5036 - val_mae: 0.4807
# Epoch 31/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4933 - mae: 0.4741 - val_loss: 0.4909 - val_mae: 0.4743
# Epoch 32/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4906 - mae: 0.4734 - val_loss: 0.4898 - val_mae: 0.4734
# Epoch 33/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4861 - mae: 0.4722 - val_loss: 0.4892 - val_mae: 0.4734
# Epoch 34/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4844 - mae: 0.4718 - val_loss: 0.4888 - val_mae: 0.4732
# Epoch 35/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4877 - mae: 0.4725 - val_loss: 0.4866 - val_mae: 0.4718
# Epoch 36/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.4889 - mae: 0.4715 - val_loss: 0.4860 - val_mae: 0.4723
# Epoch 37/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4882 - mae: 0.4717 - val_loss: 0.4860 - val_mae: 0.4721
# Epoch 38/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4822 - mae: 0.4710 - val_loss: 0.4858 - val_mae: 0.4720
# Epoch 39/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4829 - mae: 0.4700 - val_loss: 0.4845 - val_mae: 0.4706
# Epoch 40/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4833 - mae: 0.4698 - val_loss: 0.4836 - val_mae: 0.4709
# Epoch 41/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4790 - mae: 0.4684 - val_loss: 0.4837 - val_mae: 0.4708
# Epoch 42/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4823 - mae: 0.4697 - val_loss: 0.4814 - val_mae: 0.4698
# Epoch 43/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4768 - mae: 0.4684 - val_loss: 0.4904 - val_mae: 0.4731
# Epoch 44/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4812 - mae: 0.4696 - val_loss: 0.4799 - val_mae: 0.4693
# Epoch 45/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4779 - mae: 0.4680 - val_loss: 0.4805 - val_mae: 0.4704
# Epoch 46/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4745 - mae: 0.4667 - val_loss: 0.4786 - val_mae: 0.4686
# Epoch 47/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.4736 - mae: 0.4668 - val_loss: 0.4766 - val_mae: 0.4677
# Epoch 48/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4783 - mae: 0.4668 - val_loss: 0.4752 - val_mae: 0.4670
# Epoch 49/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4779 - mae: 0.4672 - val_loss: 0.4751 - val_mae: 0.4668
# Epoch 50/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4738 - mae: 0.4657 - val_loss: 0.4736 - val_mae: 0.4675
# 6219/6219 ━━━━━━━━━━━━━━━━━━━━ 3s 465us/step
#
# Anomaly Detection Threshold: 1.094591
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 1s 519us/step
#
# Confusion Matrix:
# [[81131  4176]
#  [   18   118]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97     85307
#            1       0.03      0.87      0.05       136
#
#     accuracy                           0.95     85443
#    macro avg       0.51      0.91      0.51     85443
# weighted avg       1.00      0.95      0.97     85443
