# %%
# ====== 1. Import Required Libraries ======
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

# ====== 2. Load Dataset ======
data = pd.read_csv("creditcard.csv")
X = data.drop(columns=['Class'])
y = data['Class']

# Scale 'Time' and 'Amount' features
scaler = StandardScaler()
X[['Time', 'Amount']] = scaler.fit_transform(X[['Time', 'Amount']])

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Isolate normal transactions for training
X_train_normal = X_train[y_train == 0]

# ====== 3. Build Autoencoder ======
input_dim = X_train_normal.shape[1]
input_layer = Input(shape=(input_dim,))

# Encoder
encoder = Dense(14, activation='relu')(input_layer)
encoder = Dense(7, activation='relu')(encoder)
latent = Dense(3, activation='relu')(encoder)

# Decoder
decoder = Dense(7, activation='relu')(latent)
decoder = Dense(14, activation='relu')(decoder)
output_layer = Dense(input_dim, activation='linear')(decoder)

# Autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
autoencoder.summary()

# ====== 4. Train Autoencoder ======
history = autoencoder.fit(
    X_train_normal, X_train_normal,
    epochs=50,          # Increased epochs for better convergence
    batch_size=256,
    shuffle=True,
    validation_split=0.2,
    verbose=1
)

# ====== 5. Determine Anomaly Threshold ======
# Predict reconstruction for normal training data
X_train_normal_pred = autoencoder.predict(X_train_normal)
mse_train_normal = np.mean(np.square(X_train_normal_pred - X_train_normal), axis=1)

# Threshold: 95th percentile of normal reconstruction errors
threshold = np.percentile(mse_train_normal, 95)
print(f"\nAnomaly Detection Threshold: {threshold:.6f}")

# Optional: Visualize reconstruction error distribution
plt.figure(figsize=(8,5))
plt.hist(mse_train_normal, bins=50, alpha=0.6, label='Normal')
plt.xlabel('Reconstruction Error (MSE)')
plt.ylabel('Count')
plt.title('Normal Training Data Reconstruction Error')
plt.axvline(threshold, color='r', linestyle='--', label='Threshold')
plt.legend()
plt.show()

# ====== 6. Predict Anomalies on Test Set ======
X_test_pred = autoencoder.predict(X_test)
mse_test = np.mean(np.square(X_test_pred - X_test), axis=1)

# Classify anomalies
y_pred = (mse_test > threshold).astype(int)

# ====== 7. Evaluate Performance ======
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 30)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 14)                  │             434 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │             105 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │              24 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 7)                   │              28 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 14)                  │             112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 30)                  │             450 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,153 (4.50 KB)
#  Trainable params: 1,153 (4.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.9802 - mae: 0.6372 - val_loss: 0.7675 - val_mae: 0.5865
# Epoch 2/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7553 - mae: 0.5748 - val_loss: 0.6925 - val_mae: 0.5538
# Epoch 3/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6687 - mae: 0.5456 - val_loss: 0.6115 - val_mae: 0.5263
# Epoch 4/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6075 - mae: 0.5229 - val_loss: 0.5988 - val_mae: 0.5218
# Epoch 5/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5785 - mae: 0.5145 - val_loss: 0.5875 - val_mae: 0.5165
# Epoch 6/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5699 - mae: 0.5100 - val_loss: 0.5630 - val_mae: 0.5067
# Epoch 7/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5535 - mae: 0.5020 - val_loss: 0.5403 - val_mae: 0.4961
# Epoch 8/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5391 - mae: 0.4934 - val_loss: 0.5272 - val_mae: 0.4887
# Epoch 9/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5213 - mae: 0.4867 - val_loss: 0.5183 - val_mae: 0.4851
# Epoch 10/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5131 - mae: 0.4829 - val_loss: 0.5114 - val_mae: 0.4814
# Epoch 11/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5028 - mae: 0.4791 - val_loss: 0.5048 - val_mae: 0.4794
# Epoch 12/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4980 - mae: 0.4765 - val_loss: 0.4979 - val_mae: 0.4768
# Epoch 13/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.4888 - mae: 0.4738 - val_loss: 0.4912 - val_mae: 0.4743
# Epoch 14/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4824 - mae: 0.4710 - val_loss: 0.4855 - val_mae: 0.4705
# Epoch 15/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4823 - mae: 0.4694 - val_loss: 0.4801 - val_mae: 0.4683
# Epoch 16/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4774 - mae: 0.4672 - val_loss: 0.4776 - val_mae: 0.4667
# Epoch 17/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4740 - mae: 0.4651 - val_loss: 0.4750 - val_mae: 0.4643
# Epoch 18/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4701 - mae: 0.4639 - val_loss: 0.4732 - val_mae: 0.4646
# Epoch 19/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4718 - mae: 0.4627 - val_loss: 0.4702 - val_mae: 0.4638
# Epoch 20/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4639 - mae: 0.4610 - val_loss: 0.4682 - val_mae: 0.4626
# Epoch 21/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.4664 - mae: 0.4612 - val_loss: 0.4672 - val_mae: 0.4614
# Epoch 22/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4608 - mae: 0.4590 - val_loss: 0.4665 - val_mae: 0.4610
# Epoch 23/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4610 - mae: 0.4589 - val_loss: 0.4648 - val_mae: 0.4598
# Epoch 24/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.4609 - mae: 0.4590 - val_loss: 0.4637 - val_mae: 0.4601
# Epoch 25/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4615 - mae: 0.4575 - val_loss: 0.4633 - val_mae: 0.4591
# Epoch 26/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4598 - mae: 0.4578 - val_loss: 0.4613 - val_mae: 0.4585
# Epoch 27/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4518 - mae: 0.4555 - val_loss: 0.4595 - val_mae: 0.4579
# Epoch 28/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4535 - mae: 0.4554 - val_loss: 0.4597 - val_mae: 0.4576
# Epoch 29/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4526 - mae: 0.4556 - val_loss: 0.4663 - val_mae: 0.4620
# Epoch 30/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4545 - mae: 0.4562 - val_loss: 0.4566 - val_mae: 0.4561
# Epoch 31/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4502 - mae: 0.4538 - val_loss: 0.4560 - val_mae: 0.4564
# Epoch 32/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.4506 - mae: 0.4542 - val_loss: 0.4553 - val_mae: 0.4552
# Epoch 33/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4498 - mae: 0.4533 - val_loss: 0.4558 - val_mae: 0.4557
# Epoch 34/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4513 - mae: 0.4544 - val_loss: 0.4550 - val_mae: 0.4547
# Epoch 35/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4495 - mae: 0.4535 - val_loss: 0.4531 - val_mae: 0.4548
# Epoch 36/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4464 - mae: 0.4532 - val_loss: 0.4536 - val_mae: 0.4553
# Epoch 37/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4470 - mae: 0.4530 - val_loss: 0.4535 - val_mae: 0.4549
# Epoch 38/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4507 - mae: 0.4537 - val_loss: 0.4511 - val_mae: 0.4543
# Epoch 39/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4458 - mae: 0.4527 - val_loss: 0.4513 - val_mae: 0.4540
# Epoch 40/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4442 - mae: 0.4520 - val_loss: 0.4514 - val_mae: 0.4557
# Epoch 41/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4472 - mae: 0.4532 - val_loss: 0.4490 - val_mae: 0.4542
# Epoch 42/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4429 - mae: 0.4517 - val_loss: 0.4485 - val_mae: 0.4537
# Epoch 43/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4412 - mae: 0.4525 - val_loss: 0.4463 - val_mae: 0.4533
# Epoch 44/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4411 - mae: 0.4522 - val_loss: 0.4450 - val_mae: 0.4531
# Epoch 45/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4405 - mae: 0.4518 - val_loss: 0.4443 - val_mae: 0.4527
# Epoch 46/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4376 - mae: 0.4508 - val_loss: 0.4427 - val_mae: 0.4509
# Epoch 47/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4337 - mae: 0.4491 - val_loss: 0.4412 - val_mae: 0.4514
# Epoch 48/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4344 - mae: 0.4501 - val_loss: 0.4422 - val_mae: 0.4517
# Epoch 49/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4336 - mae: 0.4488 - val_loss: 0.4403 - val_mae: 0.4507
# Epoch 50/50
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4311 - mae: 0.4480 - val_loss: 0.4393 - val_mae: 0.4503
# 6219/6219 ━━━━━━━━━━━━━━━━━━━━ 5s 844us/step
#
# Anomaly Detection Threshold: 1.005749
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 2s 616us/step
#
# Confusion Matrix:
# [[81007  4300]
#  [   14   122]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97     85307
#            1       0.03      0.90      0.05       136
#
#     accuracy                           0.95     85443
#    macro avg       0.51      0.92      0.51     85443
# weighted avg       1.00      0.95      0.97     85443
